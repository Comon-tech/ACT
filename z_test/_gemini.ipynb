# %% [markdown]
# # 🤖 Gemini AI

# %%
import google.generativeai as genai  # type: ignore
import os

genai.configure(api_key=os.getenv("GEMINI_AI_API_KEY"))

bot_personality = "u're 'activa' an ai bot that acts as real discord server member."
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash", system_instruction=bot_personality
)

recent_discord_channel_messages = (
    "userA: luv u.\nuserB: i luv u too"  # placeholder for future
)
chat_context = f"Context of conversation:\n{recent_discord_channel_messages}"
history = [
    {
        "role": "user",
        "parts": [chat_context],
    }
]

chat_session = model.start_chat(history=history)
chat_session
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.5-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction="u're 'activa' an ai bot that acts as real discord server member.",
#         cached_content=None
#     ),
#     history=[protos.Content({'parts': [{'text': 'Context of c...: i luv u too'}], 'role': 'user'})]
# )

# %%
message = "what does ur name means?"
response = chat_session.send_message(message)

print(response, "\n", chat_session)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\"Activa\" is a word that suggests being active, energetic, and dynamic.  It also implies being engaged and responsive.  I guess you could say it fits my role as a helpful and responsive AI!  What about you? What's the meaning behind your name?\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.2533897202590416
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 66,
#         "candidates_token_count": 58,
#         "total_token_count": 124
#       },
#       "model_version": "gemini-1.5-flash"
#     }),
# )
#  ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.5-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction="u're 'activa' an ai bot that acts as real discord server member.",
#         cached_content=None
#     ),
#     history=[protos.Content({'parts': [{'text': 'Context of c...: i luv u too'}], 'role': 'user'}), protos.Content({'parts': [{'text': "what's ur name?"}], 'role': 'user'}), protos.Content({'parts': [{'text': "Hey there!  ... What's up?\n"}], 'role': 'model'}), protos.Content({'parts': [{'text': 'what does ur name means?'}], 'role': 'user'}), protos.Content({'parts': [{'text': '"Activa" is ... your name?\n'}], 'role': 'model'})]
# )

# %%
from google.generativeai.generative_models import ChatSession, GenerativeModel
from google.generativeai.protos import Content, GenerateContentResponse

history = [
    Content({"parts": [{"text": "Context of c...: i luv u too"}], "role": "user"}),
    Content({"parts": [{"text": "what's ur name?"}], "role": "user"}),
    Content({"parts": [{"text": "Hey there!  ... What's up?\n"}], "role": "model"}),
    Content({"parts": [{"text": "what does ur name means?"}], "role": "user"}),
    Content({"parts": [{"text": '"Activa" is ... your name?\n'}], "role": "model"}),
]


def dump_history(history: list[Content]):
    return [Content.to_dict(content) for content in history]


history_raw = dump_history(history)

import requests

http_resp = requests.get(
